# %%
import numpy as np
a=np.array([1,2,3,4])
b=np.array([5,4,6,7])
c=np.array([7,8,9,2])
print(a+b+c)
# Out:
# [13 14 18 13]

# %%
x=np.array([
[1,5],
[4,6],
[9,8],
[7,6]
])

# %%
np.dot([1,2],[4,5])
# Out:
# np.int64(14)

# %%
import numpy as np
scores=[7.0,8.4,8.3,8.1]
print(np.mean(scores))
# Out:
# 7.950000000000001

# %%
import random
outcomes=["spam",["not spam"]]
print(random.choice(outcomes))
# Out:
# spam

# %%
w=8
ir=0.6
for i in range(8):
  w=w-ir*2*w
  print(w)
# Out:
# -1.5999999999999996
# 0.31999999999999984
# -0.06399999999999995
# 0.012799999999999992
# -0.002559999999999998
# 0.0005119999999999994
# -0.00010239999999999989
# 2.0479999999999967e-05
