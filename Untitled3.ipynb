# %%
crop=input("enter crop name:")
if (crop=="tomato"):
  print("tomato growth stages")
  print("1.seedling stage")
  print("2.vegetativestage")
  print("3.flowering stage")
  print("4.fruit development stage")
else:
  print("crop not desired")
