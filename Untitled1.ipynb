# %%
Plant_growth=True
nutrient_dificiencies=False
print("AND:",plant_growth and nutrient_dificiencies)
print("OR:",plant_growth or nutrient_dificiencies)
print("NOT:",not nutrient_dificiencies)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-774077788.py in <cell line: 0>()
#       1 Plant_growth=True
#       2 nutrient_dificiencies=False
# ----> 3 print("AND:",plant_growth and nutrient_dificiencies)
#       4 print("OR:",plant_growth or nutrient_dificiencies)
#       5 print("NOT:",not nutrient_dificiencies)
#
# NameError: name 'plant_growth' is not defined
