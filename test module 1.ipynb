# %%
name="ashwini"
age=21
print("hello,",name)
print("you are",age,"years old.")
# Out:
# hello, ashwini
# you are 21 years old.

# %%
msg="hello ashwini"
print(msg.replace("hello", ""),"welcome to python")
# Out:
#  ashwini welcome to python

# %%
x=5
y=2
z=x+y*3
print(z)
# Out:
# 11

# %%
a=10
b=a-3
a=a+1
print(a,b)
# Out:
# 11 7

# %%
mark1=50
mark2=60
mark3=40
total=mark1+mark2+mark3
print(total)
average=total/3
print(average)
print("total=",total)
print("average=",average)
# Out:
# 150
# 50.0
# total= 150
# average= 50.0

# %%
a=10
b=int("5")
c=a+b
print(c)
# Out:
# 15

# %%
mark=int(input("enter mark:"))
if(mark>=90):
 print("grade a")
elif(mark>=70):
  print("grade b")
else:
    print("grade c")
# Out:
# enter mark:75
# grade b

# %%
age=int(input("enter age"))
if(age<12):
  print("disount")
else:
  print("no discount")
# Out:
# enter age10
# disount

# %%
n=5
total=0
for i in range(n):
 total=total+i
 print("sum=",total)
# Out:
# sum= 0
# sum= 1
# sum= 3
# sum= 6
# sum= 10

# %%
rows=int(input("enter number of rows:"))
for i in range(1,rows+1):
  print("*"*i)
# Out:
# enter number of rows:3
# *
# **
# ***

# %%
marks=[56,78,90,45,88]
max_mark=max(marks)
total=0
for m in marks:
  total=total+m
print("total=",total)
count=0
for m in marks:
  if(m>60):
    count=count+1
print("max mark=",max_mark)
print("average=",average)
print("count=",count)
# Out:
# total= 357
# max mark= 90
# average= 50.0
# count= 3

# %%
numbers=[10,-3.5,0,8,-2]
count=0
for n in numbers:
  if(n>0):
    count=count+1
print("count=",count)
# Out:
# count= 2

# %%
def average_marks(marks_list):
  total= 0
  for m in marks_list:
    total=total + m
    average=total/len(marks_list)
    return average
data=[60,70,80]
print("average=",average_marks(data))
# Out:
# average= 20.0

# %%
age=int(input("enter age"))
if(age<12):
  print("50% disount")
elif(age>60):
  print("30% discount")
else:
  print("no discount")
# Out:
# enter age40
# no discount
